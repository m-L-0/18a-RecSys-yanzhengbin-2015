# %%
# 矩阵分解的协同过滤算法
import numpy as np
import random
import math as math
def load_data(path):
    f = open(path)
    data = []
    for line in f.readlines():
        arr = []
        lines = line.strip().split("\t")
        for x in lines[2]:
            if x != "-":
                arr.append(float(x))
            else:
                arr.append(float(0))
        data.append(arr)
    return data


def gradAscent(data, k):
    dataMat = np.mat(data)
    m, n = np.shape(dataMat)
    p = np.mat(np.random.random((m, k)))
    q = np.mat(np.random.random((k, n)))
    
    alpha = 0.0002
    beta = 0.02
    maxCycles = 1000 # 梯度下降的次数
    
    for step in range(maxCycles):
        for i in range(m):
            for j in range(n):
                if dataMat[i, j] > 0:
                    error = dataMat[i, j]
                    for lk in range(k):
                        error = error - p[i, lk] * q[lk, j]
                    for lk in range(k):
                        p[i, lk] = p[i, lk] + alpha * (2 * error * q[lk, j] - beta * p[i, lk])
                        q[lk, j] = q[lk, j] + alpha * (2 * error * p[i, lk] - beta * q[lk, j])
        loss = 0.0
        for i in range(m):
            for j in range(n):
                if dataMat[i, j] > 0:
                    error = 0.0
                    for lk in range(k):
                        error = error + p[i, lk] * q[lk, j]
                    loss = (dataMat[i, j] - error) * (dataMat[i, j] - error)
                    for lk in range(k):
                        loss = loss + beta * (p[i, lk] * p[i, lk] + q[lk, j] * q[lk, j]) / 2
        if loss < 0.001:
            break
        if step == 999:
            print("loss is %f" %loss)
    return p, q


# 数据集是自己写的，在movielens的u.data的基础上对几项用户的评分改成了'-'
data = load_data("./movielens/ml-100k/yzb.test")
p, q = gradAscent(data, 5)
result = p * q
total_num = 0
correct_num = 0
for i in range(len(data)):
    if data[i][0] == 0.0:
        continue
    else:
        total_num += 1
        if result[i][0] - math.floor(result[i][0]) < 0.5:
            if math.floor(result[i][0]) == data[i][0]:
                correct_num += 1
        else:
            if math.ceil(result[i][0]) == data[i][0]:
                correct_num += 1
print("正确率：%d"%(correct_num / total_num * 100) + '%')
for i in range(len(data)):
    print("true score: %f, predict score: %f" %(data[i][0], result[i][0]))
# Out:
# loss is 0.111604
# 正确率：100%
# true score: 3.000000, predict score: 2.998761
# true score: 3.000000, predict score: 3.018658
# true score: 0.000000, predict score: 4.333714
# true score: 2.000000, predict score: 2.012023
# true score: 1.000000, predict score: 1.035956
# true score: 4.000000, predict score: 3.995867
# true score: 2.000000, predict score: 1.985343
# true score: 5.000000, predict score: 4.921424
# true score: 3.000000, predict score: 3.015782
# true score: 3.000000, predict score: 3.008292
# true score: 2.000000, predict score: 2.025793
# true score: 5.000000, predict score: 4.964102
# true score: 5.000000, predict score: 4.943622
# true score: 0.000000, predict score: 1.943032
# true score: 3.000000, predict score: 3.016969
# true score: 3.000000, predict score: 3.022538
# true score: 5.000000, predict score: 4.941702
# true score: 2.000000, predict score: 2.028717
# true score: 4.000000, predict score: 3.990264
# true score: 2.000000, predict score: 1.991787
# true score: 4.000000, predict score: 3.959860
# true score: 4.000000, predict score: 3.962122
# true score: 0.000000, predict score: 3.317837
# true score: 2.000000, predict score: 2.018376
# true score: 4.000000, predict score: 3.937842
# true score: 2.000000, predict score: 2.008712
# true score: 5.000000, predict score: 4.936411
# true score: 2.000000, predict score: 2.000474
# true score: 4.000000, predict score: 3.989127
# true score: 5.000000, predict score: 4.939167
# true score: 0.000000, predict score: 4.330107
# true score: 4.000000, predict score: 3.958206
# true score: 4.000000, predict score: 3.993561
# true score: 4.000000, predict score: 3.979666
# true score: 3.000000, predict score: 2.981944
# true score: 0.000000, predict score: 2.911382
# true score: 1.000000, predict score: 1.051357
# true score: 5.000000, predict score: 4.969395
# true score: 1.000000, predict score: 1.026297
# true score: 4.000000, predict score: 3.970490
# true score: 0.000000, predict score: 4.780529
# true score: 3.000000, predict score: 3.003943
# true score: 2.000000, predict score: 2.016414
# true score: 4.000000, predict score: 3.941065
# true score: 4.000000, predict score: 3.988357
# true score: 4.000000, predict score: 3.978814
# true score: 4.000000, predict score: 3.982723
# true score: 3.000000, predict score: 2.975677
# true score: 5.000000, predict score: 4.959253
# true score: 2.000000, predict score: 2.044597
# true score: 3.000000, predict score: 2.983853
# true score: 3.000000, predict score: 2.977710
# true score: 5.000000, predict score: 4.936165
# true score: 5.000000, predict score: 4.962006
# true score: 3.000000, predict score: 3.021156
# true score: 4.000000, predict score: 3.947555
# true score: 5.000000, predict score: 4.953130
# true score: 4.000000, predict score: 3.958299
# true score: 5.000000, predict score: 4.951121
# true score: 3.000000, predict score: 3.024760
# true score: 3.000000, predict score: 2.990771
# true score: 1.000000, predict score: 1.054262
# true score: 4.000000, predict score: 3.949607
# true score: 0.000000, predict score: 3.480608
# true score: 1.000000, predict score: 1.028421
# true score: 2.000000, predict score: 2.051022
# true score: 3.000000, predict score: 3.011786
# true score: 4.000000, predict score: 3.958765
# true score: 5.000000, predict score: 4.972981
# true score: 3.000000, predict score: 2.979095
# true score: 3.000000, predict score: 3.010961
# true score: 0.000000, predict score: 5.133202
# true score: 3.000000, predict score: 3.014477
# true score: 5.000000, predict score: 4.969594
# true score: 3.000000, predict score: 2.993754
# true score: 4.000000, predict score: 3.949567
# true score: 5.000000, predict score: 4.964495
# true score: 5.000000, predict score: 4.940008
# true score: 4.000000, predict score: 4.011292
# true score: 3.000000, predict score: 2.951351
# true score: 4.000000, predict score: 3.961870
# true score: 3.000000, predict score: 3.018960
# true score: 3.000000, predict score: 3.014058
# true score: 5.000000, predict score: 4.937012
# true score: 5.000000, predict score: 4.965361
# true score: 5.000000, predict score: 4.945496
# true score: 5.000000, predict score: 4.971186
# true score: 5.000000, predict score: 4.913335
# true score: 2.000000, predict score: 2.049896
# true score: 0.000000, predict score: 2.377003
# true score: 4.000000, predict score: 3.942892
# true score: 4.000000, predict score: 3.995659
# true score: 2.000000, predict score: 2.023241
# true score: 5.000000, predict score: 4.929497
# true score: 0.000000, predict score: 1.608639
# true score: 4.000000, predict score: 4.006938
# true score: 1.000000, predict score: 1.007806
# true score: 4.000000, predict score: 3.966844
# true score: 3.000000, predict score: 3.008190
# true score: 1.000000, predict score: 1.059728
# true score: 4.000000, predict score: 3.973324
# true score: 4.000000, predict score: 3.945133
# true score: 4.000000, predict score: 3.953485
# true score: 3.000000, predict score: 2.958543
# true score: 1.000000, predict score: 1.032526
# true score: 5.000000, predict score: 4.938080
# true score: 3.000000, predict score: 3.018380
# true score: 5.000000, predict score: 4.957928
# true score: 5.000000, predict score: 4.949517
# true score: 1.000000, predict score: 1.045156
# true score: 5.000000, predict score: 4.979856
# true score: 4.000000, predict score: 3.954286
# true score: 3.000000, predict score: 3.000229
# true score: 3.000000, predict score: 3.022886
# true score: 4.000000, predict score: 3.950340
# true score: 4.000000, predict score: 3.969545
# true score: 5.000000, predict score: 4.931815
# true score: 1.000000, predict score: 1.047114
# true score: 4.000000, predict score: 3.966869
# true score: 0.000000, predict score: 3.394820
# true score: 2.000000, predict score: 2.027015
# true score: 4.000000, predict score: 3.968490
# true score: 4.000000, predict score: 3.966188
# true score: 2.000000, predict score: 2.040745
# true score: 5.000000, predict score: 4.961530
# true score: 1.000000, predict score: 1.041302
# true score: 1.000000, predict score: 1.064698
# true score: 4.000000, predict score: 3.982768
# true score: 4.000000, predict score: 3.984002
# true score: 2.000000, predict score: 2.018269
# true score: 5.000000, predict score: 4.957616
# true score: 4.000000, predict score: 3.954568
# true score: 4.000000, predict score: 3.980589
# true score: 5.000000, predict score: 4.951913
# true score: 2.000000, predict score: 2.003761
# true score: 3.000000, predict score: 3.007986
# true score: 4.000000, predict score: 3.976657
# true score: 5.000000, predict score: 4.936681
# true score: 5.000000, predict score: 4.939914
# true score: 3.000000, predict score: 2.985561
# true score: 2.000000, predict score: 2.024858
# true score: 4.000000, predict score: 3.925352
# true score: 4.000000, predict score: 3.958723
# true score: 3.000000, predict score: 3.015909
# true score: 0.000000, predict score: 3.805241
# true score: 4.000000, predict score: 3.956632
# true score: 4.000000, predict score: 3.954205
# true score: 3.000000, predict score: 3.004025
# true score: 1.000000, predict score: 1.038134
# true score: 4.000000, predict score: 3.982387
# true score: 3.000000, predict score: 2.976902
# true score: 4.000000, predict score: 3.936302
# true score: 3.000000, predict score: 3.012046
# true score: 0.000000, predict score: 3.028227
# true score: 5.000000, predict score: 4.945348
# true score: 5.000000, predict score: 4.933703
# true score: 3.000000, predict score: 2.997175
# true score: 4.000000, predict score: 3.989017
# true score: 4.000000, predict score: 3.965547
# true score: 3.000000, predict score: 2.982889
# true score: 5.000000, predict score: 4.944634
# true score: 0.000000, predict score: 2.241081
# true score: 5.000000, predict score: 4.987323
# true score: 4.000000, predict score: 3.959355
# true score: 5.000000, predict score: 4.940990
# true score: 4.000000, predict score: 3.964082
# true score: 3.000000, predict score: 2.992633
# true score: 4.000000, predict score: 3.954974
# true score: 4.000000, predict score: 3.969673
# true score: 0.000000, predict score: 3.156283
# true score: 5.000000, predict score: 4.939996
# true score: 5.000000, predict score: 4.955131
# true score: 3.000000, predict score: 3.020472

# %%
from math import ceil
print(ceil(2.01))
# Out:
# 3
